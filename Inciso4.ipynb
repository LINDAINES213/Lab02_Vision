# %% [markdown]
# ## Inciso 4
#
# Obtención del gradiente morfológico de una imagen

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io, color
from skimage.morphology import disk, dilation, erosion

# %%
imagen = io.imread('brain-scan.jpeg', as_gray=True)

# Conversión a formato de 8 bits (0-255)
imagen = (imagen * 255).astype(np.uint8)

selem = disk(2)

# Calculo del gradiente morfológico
gradiente = dilation(imagen, selem) - erosion(imagen, selem)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].imshow(imagen, cmap='gray')
ax[0].set_title('Imagen Original')
ax[0].axis('off')

ax[1].imshow(gradiente, cmap='gray')
ax[1].set_title('Gradiente Morfológico')
ax[1].axis('off')

plt.show()

# %% [markdown]
# ### Prueba con otra imagen

# %%
imagen = io.imread('butterfly.jpeg', as_gray=True)

# Conversión a formato de 8 bits (0-255)
imagen = (imagen * 255).astype(np.uint8)

selem = disk(2)

# Calculo del gradiente morfológico
gradiente = dilation(imagen, selem) - erosion(imagen, selem)

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))

ax[0].imshow(imagen, cmap='gray')
ax[0].set_title('Imagen Original')
ax[0].axis('off')

ax[1].imshow(gradiente, cmap='gray')
ax[1].set_title('Gradiente Morfológico')
ax[1].axis('off')

plt.show()
